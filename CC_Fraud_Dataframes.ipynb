# %% [markdown]
#  This notebook is for the review of the Tar file extracted as card_transaction.v1.csv.
#
#  The file is read into a dataframe and column names, volumes and datatypes printed to see the df structure.
#
#  the file is resized and exported to a new csv file that contains only 2020 trnasaction data.

# %%
import pandas as pd

# %%
df= pd.read_csv('card_transaction.v1.csv')

df
# Out:
#           User  Card  Year  Month  Day   Time   Amount           Use Chip  \
# 0            0     0  2002      9    1  06:21  $134.09  Swipe Transaction
# 1            0     0  2002      9    1  06:42   $38.48  Swipe Transaction
# 2            0     0  2002      9    2  06:22  $120.34  Swipe Transaction
# 3            0     0  2002      9    2  17:45  $128.95  Swipe Transaction
# 4            0     0  2002      9    3  06:23  $104.71  Swipe Transaction
# ...        ...   ...   ...    ...  ...    ...      ...                ...
# 24386895  1999     1  2020      2   27  22:23  $-54.00   Chip Transaction
# 24386896  1999     1  2020      2   27  22:24   $54.00   Chip Transaction
# 24386897  1999     1  2020      2   28  07:43   $59.15   Chip Transaction
# 24386898  1999     1  2020      2   28  20:10   $43.12   Chip Transaction
# 24386899  1999     1  2020      2   28  23:10   $45.13   Chip Transaction
#
#                 Merchant Name  Merchant City Merchant State      Zip   MCC  \
# ...

# %%
df.columns
# Out:
# Index(['User', 'Card', 'Year', 'Month', 'Day', 'Time', 'Amount', 'Use Chip',
#        'Merchant Name', 'Merchant City', 'Merchant State', 'Zip', 'MCC',
#        'Errors?', 'Is Fraud?'],
#       dtype='object')

# %%
df['Year'].value_counts()
# Out:
# 2019    1723938
# 2017    1723360
# 2018    1721615
# 2016    1708924
# 2015    1701371
# 2014    1672343
# 2013    1650917
# 2012    1610829
# 2011    1570551
# 2010    1491225
# 2009    1355434
# 2008    1223460
# 2007    1064483
# 2006     908793
# 2005     746653
# 2004     597003
# 2003     466408
# 2002     350732
# 2020     336500
# 2001     257998
# 2000     177729
# 1999     118250
# 1998      78345
# 1997      49753
# 1996      29945
# 1995      20928
# 1994      14316
# 1993       8378
# 1992       5134
# 1991       1585
# Name: Year, dtype: int64

# %%
df.dtypes
# Out:
# User                int64
# Card                int64
# Year                int64
# Month               int64
# Day                 int64
# Time               object
# Amount             object
# Use Chip           object
# Merchant Name       int64
# Merchant City      object
# Merchant State     object
# Zip               float64
# MCC                 int64
# Errors?            object
# Is Fraud?          object
# dtype: object

# %%
#reducing the df to 2020 only
df_2016=df[df['Year']==2016]

df_2016
# Out:
#           User  Card  Year  Month  Day   Time    Amount            Use Chip  \
# 4136         0     0  2016      1    3  10:48    $66.48    Chip Transaction
# 4137         0     0  2016      1    4  06:43    $40.02    Chip Transaction
# 4138         0     0  2016      1    7  09:30    $54.11    Chip Transaction
# 4139         0     0  2016      1    7  16:03    $89.48    Chip Transaction
# 4140         0     0  2016      1   10  06:38    $29.15    Chip Transaction
# ...        ...   ...   ...    ...  ...    ...       ...                 ...
# 24379811  1998     0  2016     12   29  11:25  $-474.00   Swipe Transaction
# 24379812  1998     0  2016     12   29  12:06   $143.38   Swipe Transaction
# 24379813  1998     0  2016     12   29  12:27  $-495.00   Swipe Transaction
# 24379814  1998     0  2016     12   31  15:38    $85.05   Swipe Transaction
# 24379815  1998     0  2016     12   31  18:13    $47.64  Online Transaction
#
# ...

# %%
# check is Fraud? column for both answers.

# %%
#export to a Csv
df_2016.to_csv("CCF2016.csv", index=False)
